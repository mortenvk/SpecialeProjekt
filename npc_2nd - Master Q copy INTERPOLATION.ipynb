# %%
import random
import numpy as np
import matplotlib
import numba
import time
import multiprocessing as mp
from numba import jit, prange
from numba import config, njit, threading_layer
from matplotlib import pyplot as plt

# %% [markdown]
# ### NOTEBOOK 3
# ### Indhold:
# Oprindelige Prisoner's dilemma, en npc_player, en 2nd generation npc player der undercutter efter 3 Coop, og så går den tilbage så snart den bliver straffet \
# PLUS hardcodet NPC
# Almindelig Q-learner, master Q-learner \
# Intet master-theta eller epsilon ændring over generationer

# %%
#random.seed(1235)
#Demand function from Klein (2020)
@njit
def PD_rewards(p1,p2):
    x = np.array(
            [[(3,3), (0,5)],
            [(5,0), (1,1)]]
             )
    val_p1, val_p2 = x[p1,p2]
    
    return val_p1, val_p2

# %%
@njit
def master_q_player(prices, Q, epsilon, p2,t):
    if random.uniform(0,1) < epsilon:
        p3 = int(np.random.choice(len(prices)))
        #print('now its random', epsilon)
    else:
        #p3, pyt = np.unravel_index(np.argmax(Q),Q.shape)
        p3 = int(np.argmax(Q[t,:,p2]))
    return p3

# %%
# Pavlov, 2 CC - C else 1
@njit
def npc_player(options, q_table, epsilon, prev, time):
    if prev[time-1]==0 and prev[time]==0:
        npc_choice = 0
    else:
        npc_choice = 1
    return npc_choice

# %%
#NPC: Undercut after 3 Coop
@njit
def npc_player_gen2(options, q_table, epsilon, prev_q, prev_npc, iq_counter, jnpc_counter):
    if prev_q[iq_counter-3] ==0 and prev_q[iq_counter-2]==0 and prev_q[iq_counter-1]==0:
        npc_choice = 1
        #print('Choices', prev_q, prev_npc, iq_counter, jnpc_counter)
    elif prev_q[iq_counter-4] ==0 and prev_q[iq_counter-3]==0 and prev_q[iq_counter-2]==0:
        #print(prev_npc[jnpc_counter-1])#int(prev_q[iq_counter-1])==0 and prev_npc[jnpc_counter-1]==1:
        
        npc_choice = 0
        #print('CASE')
    else:
        #print('tit4tat')
        npc_choice = int(prev_q[iq_counter-1])
    return npc_choice

# %%
# tit4tat till 1/2 then GRIM TRIGGER PLAYER 
@njit
def npc_player_gen3(periods, prev_q, prev_npc, iq_counter, jnpc_counter):
    if jnpc_counter < int(periods/4):
        npc_choice = int(prev_q[iq_counter-1])
    else:
        if np.any(prev_q[int(periods/4):]== 1):
            npc_choice = 1
        else:
            npc_choice = 0

    return npc_choice

# %%
# tit4tat till 1/2 and then Pavlov PLAYER after halfway
@njit
def npc_player_gen4(periods, prev_q, prev_npc, iq_counter, jnpc_counter):
    if jnpc_counter < int(periods/4):
        npc_choice = int(prev_q[iq_counter-1])
    elif prev_q[iq_counter-2]==0 and prev_q[iq_counter-1]==0:
        npc_choice = 0
    else:
        npc_choice = 1
    return npc_choice

# %%
# Tit for tat for two tats PLAYER
@njit
def npc_player_gen5(periods, prev_q, prev_npc, iq_counter, jnpc_counter):
    if jnpc_counter < int(periods/4):
        npc_choice = int(prev_q[iq_counter-1])
    elif prev_q[iq_counter-2]==1 and prev_q[iq_counter-1]==1:
        npc_choice = 1
    else: 
        npc_choice = 0
    return npc_choice

# %%
test = np.array([0,0,0,0,0,0,0])
print(test==1)
np.any(test[5:]==1)
# Out:
# [False False False False False False False]
# np.False_

# %%
@njit
def regular_update(Q, prev, alpha, delta, prices, indic):
     if indic == 1: 
         p1 = prev[0,0]
         p2 = prev[1,0]
         p22 = prev[1,1]
         pe1 = Q[prev[0,0],prev[1,0]]
         ne1 = PD_rewards(p1,p2)[0] + delta* PD_rewards(p1,p22)[0] + delta**2 * Q[np.argmax(Q[:,prev[1,1]]),prev[1,1]]
         Q[prev[0,0], prev[1,0]] = (1-alpha) * pe1 + alpha * ne1
     else: 
        p1 = prev[1,0]
        p2 = prev[0,0]
        p22 = prev[0,1]
        pe2 = Q[prev[1,0],prev[0,0]]

        ne2 = PD_rewards(p2,p1)[1] + delta* PD_rewards(p22,p1)[1] + delta**2 * Q[np.argmax(Q[:,prev[0,1]]),prev[0,1]]
        Q[prev[1,0], prev[0,0]] = (1-alpha) * pe2 + alpha * ne2

@njit
def simple_Q_learner(prices, Q, epsilon, p2):
    if random.uniform(0,1) < epsilon:
        p3 = int(np.random.choice(len(prices)))
        #print('now its random', epsilon)
    else:
        #p3, pyt = np.unravel_index(np.argmax(Q),Q.shape)
        p3 = int(np.argmax(Q[:,p2]))
    return p3

# %%
@njit
def update(Q, prev, alpha, delta, prices, Current_t, previous_t, time, interval, Inter_Q, i_counter):
        my_old_price = prev[0,0]
        their_old_price = prev[1,0]
        their_new_choice = prev[1,1]
        intervals = np.shape(Q)[0]
        
        # Current_t = numba.int64(np.floor(time/interval_size))
        # previous_t = numba.int64(np.floor((time-1)/interval_size))
                
        #print('indices',prev[0,0],prev[1,0],prev_time)
        #print('prices', my_old_price, their_new_choice, their_old_price)
        prev_q_est = Q[previous_t, prev[0,0],prev[1,0]]
        #print('PD_reward', PD_rewards(my_old_price,their_old_price))
        #print('argmax i Q', Q[Current_t, np.argmax(Q[Current_t,:,prev[1,1]]),prev[1,1]])
        #print("PREV", prev[0,1])
        
        
        
        new_q_est = PD_rewards(my_old_price,their_old_price)[0] + delta* PD_rewards(my_old_price,their_new_choice)[0] + delta ** 2 * Q[Current_t, np.argmax(Q[Current_t,:,prev[1,1]]),prev[1,1]]
        #print("New Q est", new_q_est)
        Inter_Q[i_counter, prev[0,0], prev[1,0]] = (1-alpha) * prev_q_est + alpha * (new_q_est)
        prev_interval = max(0,Current_t-1)
        next_interval = min(intervals-1, Current_t+1)
        
        #print("operation",(time/interval) - Current_t)
        #if (time/interval) - Current_t < 0.5:
        #        prev_w = 0.5 - abs((time/interval) - prev_interval )
        #        curr_w = 1-prev_w
        #        Q[Current_t, prev[0,0], prev[1,0]] = (1-alpha) * prev_q_est + alpha * (curr_w * new_q_est + prev_w * Q[prev_interval, prev[0,0], prev[1,0]])
        #else:
        #        next_w = 0.5 - abs((time/interval) - next_interval) 
        #        curr_w = 1-next_w
        #        Q[Current_t, prev[0,0], prev[1,0]] = (1-alpha) * prev_q_est + alpha * (curr_w * new_q_est + next_w * Q[next_interval, prev[0,0], prev[1,0]])


        w_1 =  ( next_interval - time/interval) / (next_interval - prev_interval)
        w_2 =  (time/interval - prev_interval) / (next_interval-prev_interval) 
        #print('VÆGTE!!!:', w_1, w_2) 
        Q[Current_t, prev[0,0], prev[1,0]] = (1-alpha) * prev_q_est + alpha * (w_2 * new_q_est + w_1 * Q[next_interval, prev[0,0], prev[1,0]])
        #curr_w = 1-prev_w
        #Q[Current_t, prev[0,0], prev[1,0]] = (1-alpha) * prev_q_est + alpha * (curr_w * new_q_est + next_w * Q[next_interval, prev[0,0], prev[1,0]] + prev_w * Q[prev_interval, prev[0,0], prev[1,0]])

# %%
@njit
def PD_game(q_table, options, periods, alpha, theta, delta, master_theta, inter_init_Q):
    a = len(options)
    Simple_Q_Table = np.zeros((a, a))
    Simple_Q_Table2 = np.zeros((a, a))
    interval_size = periods/15
    prev_choices = np.zeros((2,2), dtype=numba.int64)
    reward_arr = np.zeros(int(periods-2))
    reward_arr_p2 = np.zeros(int(periods-2))
    all_choices1 =np.zeros(int(periods/2)-1)
    all_choices2 =np.zeros(int(periods/2)-1)
    i_counter = 0
    j_counter = 0
    t=3
    if np.shape(q_table) != (15,a,a):
        print("Wrong dimensions")
    else:
        for t in range(t, periods+1):
        
            epsilon = (1-theta)**t
            master_epsilon = (1-master_theta)**t
            if t % 2 != 0: 
                time_for_q = int(np.floor(t/interval_size))
                prev_time_for_q = int(np.floor((t-1)/interval_size))
                #print("TimeCHeck",time_for_q,time_for_q)
                #print('time for q', time_for_q, 'prev time for q', prev_time_for_q, "prev", prev_choices)
                update(q_table, prev_choices, alpha, delta, options, time_for_q, prev_time_for_q, t, interval_size, inter_init_Q,i_counter)
                p_i =int(master_q_player(options, q_table, master_epsilon, prev_choices[1,1], time_for_q))

                #In Case of Q opponent:
                #regular_update(Simple_Q_Table, prev_choices, alpha, delta, options, 1)
                
                #p_i = simple_Q_learner(options, Simple_Q_Table, epsilon, prev_choices[1,1])
                prev_choices[0,0] = prev_choices[0,1]
                prev_choices[0,1] = p_i
                prev_choices[1,0] = prev_choices[1,1]
                all_choices1[i_counter] = int(options[p_i])
                i_counter += 1
                reward_arr[t-3], reward_arr_p2[t-3] = PD_rewards(prev_choices[0,1], prev_choices[1,1])
            else: 
                #In Case of Q opponent:
                regular_update(Simple_Q_Table2, prev_choices, alpha, delta, options, 2)
                p_j = simple_Q_learner(options, Simple_Q_Table2, epsilon, prev_choices[0,1])
                #a hard coded opponent: 
                #p_j= npc_player(options, q_table, 0, all_choices1,j_counter)
                #p_j = int(npc_player_gen2(options, q_table, 0, all_choices1, all_choices2, j_counter, i_counter))
                #p_j = int(npc_player_gen3(periods, all_choices1, all_choices2,i_counter,j_counter))
                #p_j = int(npc_player_gen4(periods, all_choices1, all_choices2,i_counter,j_counter))
                #p_j = int(npc_player_gen5(periods, all_choices1, all_choices2,i_counter,j_counter))

                prev_choices[1,0] = prev_choices[1,1]
                prev_choices[1,1] = p_j
                prev_choices[0,0] = prev_choices[0,1]
                all_choices2[j_counter] = int(options[p_j])
                j_counter += 1
                reward_arr[t-3], reward_arr_p2[t-3] = PD_rewards(prev_choices[0,1], prev_choices[1,1])
                #step_counter +=1
    return all_choices1, all_choices2, reward_arr, reward_arr_p2, q_table, inter_init_Q

# %%
def many_games(prices, periods, alpha, theta, learners, delta, init_q, init_inter_Q):
    total_pro_arr = np.zeros((learners,periods-2),dtype=np.ndarray)
    total_pro_arr2 = np.zeros((learners,periods-2),dtype=np.ndarray)
    total_opt_arr = np.zeros((learners, 49), dtype = np.ndarray)
    avg_profit = np.zeros(learners)
    avg_profit2 = np.zeros(learners)
    change_arr = np.zeros((1,25))
    change_arr2 = np.zeros((1,25))
    init_Q = init_q #np.zeros((10,2,2))
    for i in range(learners):
        print('run #',i+1 ,'of ', learners , 'runs')
        
        master_theta = theta*((i**1.25)/learners)
        #master_theta = theta
        all_choices1, all_choices2, reward_arr, reward_arr_p2, q_table, Inter_Q = PD_game(init_Q, prices, periods, alpha, theta, delta, master_theta, init_inter_Q)
        total_pro_arr[i] = reward_arr
        total_pro_arr2[i] = reward_arr_p2
        #total_opt_arr[i] = arr_opt_i
        avg_profit[i] = np.mean(reward_arr[-10000:])
        avg_profit2[i] = np.mean(reward_arr_p2[-10000:])
        init_Q = q_table
        init_inter_Q = Inter_Q
        
    return total_pro_arr, total_pro_arr2, avg_profit, avg_profit2, init_Q, all_choices1, all_choices2, Inter_Q

# %%
options = np.array([0,1])
init_Q = np.zeros((15,2,2))
local_periods = 50000
learners = 1000
init_inter_q = np.zeros((int(local_periods/2-1),2,2))
'''Periods and THETAS: '''
#100.000 periods:
#theta = 0.0000922

#200.000 periods: 
#local_periods = 200000
#theta = 0.00004605
rewards_p1, rewards_p2, avg_prof, avg_prof2, final_Q, choices1, choices2, final_inter_Q = many_games(options, local_periods, 0.3, 0.00001844, learners ,0.95, init_Q, init_inter_q)
final_Q
# Out:
# run # 1 of  1000 runs
# run # 2 of  1000 runs
# run # 3 of  1000 runs
# run # 4 of  1000 runs
# run # 5 of  1000 runs
# run # 6 of  1000 runs
# run # 7 of  1000 runs
# run # 8 of  1000 runs
# run # 9 of  1000 runs
# run # 10 of  1000 runs
# run # 11 of  1000 runs
# run # 12 of  1000 runs
# run # 13 of  1000 runs
# run # 14 of  1000 runs
# run # 15 of  1000 runs
# run # 16 of  1000 runs
# run # 17 of  1000 runs
# run # 18 of  1000 runs
# run # 19 of  1000 runs
# run # 20 of  1000 runs
# run # 21 of  1000 runs
# run # 22 of  1000 runs
# run # 23 of  1000 runs
# run # 24 of  1000 runs
# run # 25 of  1000 runs
# run # 26 of  1000 runs
# run # 27 of  1000 runs
# run # 28 of  1000 runs
# run # 29 of  1000 runs
# run # 30 of  1000 runs
# run # 31 of  1000 runs
# run # 32 of  1000 runs
# run # 33 of  1000 runs
# run # 34 of  1000 runs
# run # 35 of  1000 runs
# run # 36 of  1000 runs
# run # 37 of  1000 runs
# run # 38 of  1000 runs
# run # 39 of  1000 runs
# run # 40 of  1000 runs
# run # 41 of  1000 runs
# run # 42 of  1000 runs
# run # 43 of  1000 runs
# run # 44 of  1000 runs
# run # 45 of  1000 runs
# run # 46 of  1000 runs
# run # 47 of  1000 runs
# run # 48 of  1000 runs
# run # 49 of  1000 runs
# run # 50 of  1000 runs
# run # 51 of  1000 runs
# run # 52 of  1000 runs
# run # 53 of  1000 runs
# run # 54 of  1000 runs
# run # 55 of  1000 runs
# run # 56 of  1000 runs
# run # 57 of  1000 runs
# run # 58 of  1000 runs
# run # 59 of  1000 runs
# run # 60 of  1000 runs
# run # 61 of  1000 runs
# run # 62 of  1000 runs
# run # 63 of  1000 runs
# run # 64 of  1000 runs
# run # 65 of  1000 runs
# run # 66 of  1000 runs
# run # 67 of  1000 runs
# run # 68 of  1000 runs
# run # 69 of  1000 runs
# run # 70 of  1000 runs
# run # 71 of  1000 runs
# run # 72 of  1000 runs
# run # 73 of  1000 runs
# run # 74 of  1000 runs
# run # 75 of  1000 runs
# run # 76 of  1000 runs
# run # 77 of  1000 runs
# run # 78 of  1000 runs
# run # 79 of  1000 runs
# run # 80 of  1000 runs
# run # 81 of  1000 runs
# run # 82 of  1000 runs
# run # 83 of  1000 runs
# run # 84 of  1000 runs
# run # 85 of  1000 runs
# run # 86 of  1000 runs
# run # 87 of  1000 runs
# run # 88 of  1000 runs
# run # 89 of  1000 runs
# run # 90 of  1000 runs
# run # 91 of  1000 runs
# run # 92 of  1000 runs
# run # 93 of  1000 runs
# run # 94 of  1000 runs
# run # 95 of  1000 runs
# run # 96 of  1000 runs
# run # 97 of  1000 runs
# run # 98 of  1000 runs
# run # 99 of  1000 runs
# run # 100 of  1000 runs
# run # 101 of  1000 runs
# run # 102 of  1000 runs
# run # 103 of  1000 runs
# run # 104 of  1000 runs
# run # 105 of  1000 runs
# run # 106 of  1000 runs
# run # 107 of  1000 runs
# run # 108 of  1000 runs
# run # 109 of  1000 runs
# run # 110 of  1000 runs
# run # 111 of  1000 runs
# run # 112 of  1000 runs
# run # 113 of  1000 runs
# run # 114 of  1000 runs
# run # 115 of  1000 runs
# run # 116 of  1000 runs
# run # 117 of  1000 runs
# run # 118 of  1000 runs
# run # 119 of  1000 runs
# run # 120 of  1000 runs
# run # 121 of  1000 runs
# run # 122 of  1000 runs
# run # 123 of  1000 runs
# run # 124 of  1000 runs
# run # 125 of  1000 runs
# run # 126 of  1000 runs
# run # 127 of  1000 runs
# run # 128 of  1000 runs
# run # 129 of  1000 runs
# run # 130 of  1000 runs
# run # 131 of  1000 runs
# run # 132 of  1000 runs
# run # 133 of  1000 runs
# run # 134 of  1000 runs
# run # 135 of  1000 runs
# run # 136 of  1000 runs
# run # 137 of  1000 runs
# run # 138 of  1000 runs
# run # 139 of  1000 runs
# run # 140 of  1000 runs
# run # 141 of  1000 runs
# run # 142 of  1000 runs
# run # 143 of  1000 runs
# run # 144 of  1000 runs
# run # 145 of  1000 runs
# run # 146 of  1000 runs
# run # 147 of  1000 runs
# run # 148 of  1000 runs
# run # 149 of  1000 runs
# run # 150 of  1000 runs
# run # 151 of  1000 runs
# run # 152 of  1000 runs
# run # 153 of  1000 runs
# run # 154 of  1000 runs
# run # 155 of  1000 runs
# run # 156 of  1000 runs
# run # 157 of  1000 runs
# run # 158 of  1000 runs
# run # 159 of  1000 runs
# run # 160 of  1000 runs
# run # 161 of  1000 runs
# run # 162 of  1000 runs
# run # 163 of  1000 runs
# run # 164 of  1000 runs
# run # 165 of  1000 runs
# run # 166 of  1000 runs
# run # 167 of  1000 runs
# run # 168 of  1000 runs
# run # 169 of  1000 runs
# run # 170 of  1000 runs
# run # 171 of  1000 runs
# run # 172 of  1000 runs
# run # 173 of  1000 runs
# run # 174 of  1000 runs
# run # 175 of  1000 runs
# run # 176 of  1000 runs
# run # 177 of  1000 runs
# run # 178 of  1000 runs
# run # 179 of  1000 runs
# run # 180 of  1000 runs
# run # 181 of  1000 runs
# run # 182 of  1000 runs
# run # 183 of  1000 runs
# run # 184 of  1000 runs
# run # 185 of  1000 runs
# run # 186 of  1000 runs
# run # 187 of  1000 runs
# run # 188 of  1000 runs
# run # 189 of  1000 runs
# run # 190 of  1000 runs
# run # 191 of  1000 runs
# run # 192 of  1000 runs
# run # 193 of  1000 runs
# run # 194 of  1000 runs
# run # 195 of  1000 runs
# run # 196 of  1000 runs
# run # 197 of  1000 runs
# run # 198 of  1000 runs
# run # 199 of  1000 runs
# run # 200 of  1000 runs
# run # 201 of  1000 runs
# run # 202 of  1000 runs
# run # 203 of  1000 runs
# run # 204 of  1000 runs
# run # 205 of  1000 runs
# run # 206 of  1000 runs
# run # 207 of  1000 runs
# run # 208 of  1000 runs
# run # 209 of  1000 runs
# run # 210 of  1000 runs
# run # 211 of  1000 runs
# run # 212 of  1000 runs
# run # 213 of  1000 runs
# run # 214 of  1000 runs
# run # 215 of  1000 runs
# run # 216 of  1000 runs
# run # 217 of  1000 runs
# run # 218 of  1000 runs
# run # 219 of  1000 runs
# run # 220 of  1000 runs
# run # 221 of  1000 runs
# run # 222 of  1000 runs
# run # 223 of  1000 runs
# run # 224 of  1000 runs
# run # 225 of  1000 runs
# run # 226 of  1000 runs
# run # 227 of  1000 runs
# run # 228 of  1000 runs
# run # 229 of  1000 runs
# run # 230 of  1000 runs
# run # 231 of  1000 runs
# run # 232 of  1000 runs
# run # 233 of  1000 runs
# run # 234 of  1000 runs
# run # 235 of  1000 runs
# run # 236 of  1000 runs
# run # 237 of  1000 runs
# run # 238 of  1000 runs
# run # 239 of  1000 runs
# run # 240 of  1000 runs
# run # 241 of  1000 runs
# run # 242 of  1000 runs
# run # 243 of  1000 runs
# run # 244 of  1000 runs
# run # 245 of  1000 runs
# run # 246 of  1000 runs
# run # 247 of  1000 runs
# run # 248 of  1000 runs
# run # 249 of  1000 runs
# run # 250 of  1000 runs
# run # 251 of  1000 runs
# run # 252 of  1000 runs
# run # 253 of  1000 runs
# run # 254 of  1000 runs
# run # 255 of  1000 runs
# run # 256 of  1000 runs
# run # 257 of  1000 runs
# run # 258 of  1000 runs
# run # 259 of  1000 runs
# run # 260 of  1000 runs
# run # 261 of  1000 runs
# run # 262 of  1000 runs
# run # 263 of  1000 runs
# run # 264 of  1000 runs
# run # 265 of  1000 runs
# run # 266 of  1000 runs
# run # 267 of  1000 runs
# run # 268 of  1000 runs
# run # 269 of  1000 runs
# run # 270 of  1000 runs
# run # 271 of  1000 runs
# run # 272 of  1000 runs
# run # 273 of  1000 runs
# run # 274 of  1000 runs
# run # 275 of  1000 runs
# run # 276 of  1000 runs
# run # 277 of  1000 runs
# run # 278 of  1000 runs
# run # 279 of  1000 runs
# run # 280 of  1000 runs
# run # 281 of  1000 runs
# run # 282 of  1000 runs
# run # 283 of  1000 runs
# run # 284 of  1000 runs
# run # 285 of  1000 runs
# run # 286 of  1000 runs
# run # 287 of  1000 runs
# run # 288 of  1000 runs
# run # 289 of  1000 runs
# run # 290 of  1000 runs
# run # 291 of  1000 runs
# run # 292 of  1000 runs
# run # 293 of  1000 runs
# run # 294 of  1000 runs
# run # 295 of  1000 runs
# run # 296 of  1000 runs
# run # 297 of  1000 runs
# run # 298 of  1000 runs
# run # 299 of  1000 runs
# run # 300 of  1000 runs
# run # 301 of  1000 runs
# run # 302 of  1000 runs
# run # 303 of  1000 runs
# run # 304 of  1000 runs
# run # 305 of  1000 runs
# run # 306 of  1000 runs
# run # 307 of  1000 runs
# run # 308 of  1000 runs
# run # 309 of  1000 runs
# run # 310 of  1000 runs
# run # 311 of  1000 runs
# run # 312 of  1000 runs
# run # 313 of  1000 runs
# run # 314 of  1000 runs
# run # 315 of  1000 runs
# run # 316 of  1000 runs
# run # 317 of  1000 runs
# run # 318 of  1000 runs
# run # 319 of  1000 runs
# run # 320 of  1000 runs
# run # 321 of  1000 runs
# run # 322 of  1000 runs
# run # 323 of  1000 runs
# run # 324 of  1000 runs
# run # 325 of  1000 runs
# run # 326 of  1000 runs
# run # 327 of  1000 runs
# run # 328 of  1000 runs
# run # 329 of  1000 runs
# run # 330 of  1000 runs
# run # 331 of  1000 runs
# run # 332 of  1000 runs
# run # 333 of  1000 runs
# run # 334 of  1000 runs
# run # 335 of  1000 runs
# run # 336 of  1000 runs
# run # 337 of  1000 runs
# run # 338 of  1000 runs
# run # 339 of  1000 runs
# run # 340 of  1000 runs
# run # 341 of  1000 runs
# run # 342 of  1000 runs
# run # 343 of  1000 runs
# run # 344 of  1000 runs
# run # 345 of  1000 runs
# run # 346 of  1000 runs
# run # 347 of  1000 runs
# run # 348 of  1000 runs
# run # 349 of  1000 runs
# run # 350 of  1000 runs
# run # 351 of  1000 runs
# run # 352 of  1000 runs
# run # 353 of  1000 runs
# run # 354 of  1000 runs
# run # 355 of  1000 runs
# run # 356 of  1000 runs
# run # 357 of  1000 runs
# run # 358 of  1000 runs
# run # 359 of  1000 runs
# run # 360 of  1000 runs
# run # 361 of  1000 runs
# run # 362 of  1000 runs
# run # 363 of  1000 runs
# run # 364 of  1000 runs
# run # 365 of  1000 runs
# run # 366 of  1000 runs
# run # 367 of  1000 runs
# run # 368 of  1000 runs
# run # 369 of  1000 runs
# run # 370 of  1000 runs
# run # 371 of  1000 runs
# run # 372 of  1000 runs
# run # 373 of  1000 runs
# run # 374 of  1000 runs
# run # 375 of  1000 runs
# run # 376 of  1000 runs
# run # 377 of  1000 runs
# run # 378 of  1000 runs
# run # 379 of  1000 runs
# run # 380 of  1000 runs
# run # 381 of  1000 runs
# run # 382 of  1000 runs
# run # 383 of  1000 runs
# run # 384 of  1000 runs
# run # 385 of  1000 runs
# run # 386 of  1000 runs
# run # 387 of  1000 runs
# run # 388 of  1000 runs
# run # 389 of  1000 runs
# run # 390 of  1000 runs
# run # 391 of  1000 runs
# run # 392 of  1000 runs
# run # 393 of  1000 runs
# run # 394 of  1000 runs
# run # 395 of  1000 runs
# run # 396 of  1000 runs
# run # 397 of  1000 runs
# run # 398 of  1000 runs
# run # 399 of  1000 runs
# run # 400 of  1000 runs
# run # 401 of  1000 runs
# run # 402 of  1000 runs
# run # 403 of  1000 runs
# run # 404 of  1000 runs
# run # 405 of  1000 runs
# run # 406 of  1000 runs
# run # 407 of  1000 runs
# run # 408 of  1000 runs
# run # 409 of  1000 runs
# run # 410 of  1000 runs
# run # 411 of  1000 runs
# run # 412 of  1000 runs
# run # 413 of  1000 runs
# run # 414 of  1000 runs
# run # 415 of  1000 runs
# run # 416 of  1000 runs
# run # 417 of  1000 runs
# run # 418 of  1000 runs
# run # 419 of  1000 runs
# run # 420 of  1000 runs
# run # 421 of  1000 runs
# run # 422 of  1000 runs
# run # 423 of  1000 runs
# run # 424 of  1000 runs
# run # 425 of  1000 runs
# run # 426 of  1000 runs
# run # 427 of  1000 runs
# run # 428 of  1000 runs
# run # 429 of  1000 runs
# run # 430 of  1000 runs
# run # 431 of  1000 runs
# run # 432 of  1000 runs
# run # 433 of  1000 runs
# run # 434 of  1000 runs
# run # 435 of  1000 runs
# run # 436 of  1000 runs
# run # 437 of  1000 runs
# run # 438 of  1000 runs
# run # 439 of  1000 runs
# run # 440 of  1000 runs
# run # 441 of  1000 runs
# run # 442 of  1000 runs
# run # 443 of  1000 runs
# run # 444 of  1000 runs
# run # 445 of  1000 runs
# run # 446 of  1000 runs
# run # 447 of  1000 runs
# run # 448 of  1000 runs
# run # 449 of  1000 runs
# run # 450 of  1000 runs
# run # 451 of  1000 runs
# run # 452 of  1000 runs
# run # 453 of  1000 runs
# run # 454 of  1000 runs
# run # 455 of  1000 runs
# run # 456 of  1000 runs
# run # 457 of  1000 runs
# run # 458 of  1000 runs
# run # 459 of  1000 runs
# run # 460 of  1000 runs
# run # 461 of  1000 runs
# run # 462 of  1000 runs
# run # 463 of  1000 runs
# run # 464 of  1000 runs
# run # 465 of  1000 runs
# run # 466 of  1000 runs
# run # 467 of  1000 runs
# run # 468 of  1000 runs
# run # 469 of  1000 runs
# run # 470 of  1000 runs
# run # 471 of  1000 runs
# run # 472 of  1000 runs
# run # 473 of  1000 runs
# run # 474 of  1000 runs
# run # 475 of  1000 runs
# run # 476 of  1000 runs
# run # 477 of  1000 runs
# run # 478 of  1000 runs
# run # 479 of  1000 runs
# run # 480 of  1000 runs
# run # 481 of  1000 runs
# run # 482 of  1000 runs
# run # 483 of  1000 runs
# run # 484 of  1000 runs
# run # 485 of  1000 runs
# run # 486 of  1000 runs
# run # 487 of  1000 runs
# run # 488 of  1000 runs
# run # 489 of  1000 runs
# run # 490 of  1000 runs
# run # 491 of  1000 runs
# run # 492 of  1000 runs
# run # 493 of  1000 runs
# run # 494 of  1000 runs
# run # 495 of  1000 runs
# run # 496 of  1000 runs
# run # 497 of  1000 runs
# run # 498 of  1000 runs
# run # 499 of  1000 runs
# run # 500 of  1000 runs
# run # 501 of  1000 runs
# run # 502 of  1000 runs
# run # 503 of  1000 runs
# run # 504 of  1000 runs
# run # 505 of  1000 runs
# run # 506 of  1000 runs
# run # 507 of  1000 runs
# run # 508 of  1000 runs
# run # 509 of  1000 runs
# run # 510 of  1000 runs
# run # 511 of  1000 runs
# run # 512 of  1000 runs
# run # 513 of  1000 runs
# run # 514 of  1000 runs
# run # 515 of  1000 runs
# run # 516 of  1000 runs
# run # 517 of  1000 runs
# run # 518 of  1000 runs
# run # 519 of  1000 runs
# run # 520 of  1000 runs
# run # 521 of  1000 runs
# run # 522 of  1000 runs
# run # 523 of  1000 runs
# run # 524 of  1000 runs
# run # 525 of  1000 runs
# run # 526 of  1000 runs
# run # 527 of  1000 runs
# run # 528 of  1000 runs
# run # 529 of  1000 runs
# run # 530 of  1000 runs
# run # 531 of  1000 runs
# run # 532 of  1000 runs
# run # 533 of  1000 runs
# run # 534 of  1000 runs
# run # 535 of  1000 runs
# run # 536 of  1000 runs
# run # 537 of  1000 runs
# run # 538 of  1000 runs
# run # 539 of  1000 runs
# run # 540 of  1000 runs
# run # 541 of  1000 runs
# run # 542 of  1000 runs
# run # 543 of  1000 runs
# run # 544 of  1000 runs
# run # 545 of  1000 runs
# run # 546 of  1000 runs
# run # 547 of  1000 runs
# run # 548 of  1000 runs
# run # 549 of  1000 runs
# run # 550 of  1000 runs
# run # 551 of  1000 runs
# run # 552 of  1000 runs
# run # 553 of  1000 runs
# run # 554 of  1000 runs
# run # 555 of  1000 runs
# run # 556 of  1000 runs
# run # 557 of  1000 runs
# run # 558 of  1000 runs
# run # 559 of  1000 runs
# run # 560 of  1000 runs
# run # 561 of  1000 runs
# run # 562 of  1000 runs
# run # 563 of  1000 runs
# run # 564 of  1000 runs
# run # 565 of  1000 runs
# run # 566 of  1000 runs
# run # 567 of  1000 runs
# run # 568 of  1000 runs
# run # 569 of  1000 runs
# run # 570 of  1000 runs
# run # 571 of  1000 runs
# run # 572 of  1000 runs
# run # 573 of  1000 runs
# run # 574 of  1000 runs
# run # 575 of  1000 runs
# run # 576 of  1000 runs
# run # 577 of  1000 runs
# run # 578 of  1000 runs
# run # 579 of  1000 runs
# run # 580 of  1000 runs
# run # 581 of  1000 runs
# run # 582 of  1000 runs
# run # 583 of  1000 runs
# run # 584 of  1000 runs
# run # 585 of  1000 runs
# run # 586 of  1000 runs
# run # 587 of  1000 runs
# run # 588 of  1000 runs
# run # 589 of  1000 runs
# run # 590 of  1000 runs
# run # 591 of  1000 runs
# run # 592 of  1000 runs
# run # 593 of  1000 runs
# run # 594 of  1000 runs
# run # 595 of  1000 runs
# run # 596 of  1000 runs
# run # 597 of  1000 runs
# run # 598 of  1000 runs
# run # 599 of  1000 runs
# run # 600 of  1000 runs
# run # 601 of  1000 runs
# run # 602 of  1000 runs
# run # 603 of  1000 runs
# run # 604 of  1000 runs
# run # 605 of  1000 runs
# run # 606 of  1000 runs
# run # 607 of  1000 runs
# run # 608 of  1000 runs
# run # 609 of  1000 runs
# run # 610 of  1000 runs
# run # 611 of  1000 runs
# run # 612 of  1000 runs
# run # 613 of  1000 runs
# run # 614 of  1000 runs
# run # 615 of  1000 runs
# run # 616 of  1000 runs
# run # 617 of  1000 runs
# run # 618 of  1000 runs
# run # 619 of  1000 runs
# run # 620 of  1000 runs
# run # 621 of  1000 runs
# run # 622 of  1000 runs
# run # 623 of  1000 runs
# run # 624 of  1000 runs
# run # 625 of  1000 runs
# run # 626 of  1000 runs
# run # 627 of  1000 runs
# run # 628 of  1000 runs
# run # 629 of  1000 runs
# run # 630 of  1000 runs
# run # 631 of  1000 runs
# run # 632 of  1000 runs
# run # 633 of  1000 runs
# run # 634 of  1000 runs
# run # 635 of  1000 runs
# run # 636 of  1000 runs
# run # 637 of  1000 runs
# run # 638 of  1000 runs
# run # 639 of  1000 runs
# run # 640 of  1000 runs
# run # 641 of  1000 runs
# run # 642 of  1000 runs
# run # 643 of  1000 runs
# run # 644 of  1000 runs
# run # 645 of  1000 runs
# run # 646 of  1000 runs
# run # 647 of  1000 runs
# run # 648 of  1000 runs
# run # 649 of  1000 runs
# run # 650 of  1000 runs
# run # 651 of  1000 runs
# run # 652 of  1000 runs
# run # 653 of  1000 runs
# run # 654 of  1000 runs
# run # 655 of  1000 runs
# run # 656 of  1000 runs
# run # 657 of  1000 runs
# run # 658 of  1000 runs
# run # 659 of  1000 runs
# run # 660 of  1000 runs
# run # 661 of  1000 runs
# run # 662 of  1000 runs
# run # 663 of  1000 runs
# run # 664 of  1000 runs
# run # 665 of  1000 runs
# run # 666 of  1000 runs
# run # 667 of  1000 runs
# run # 668 of  1000 runs
# run # 669 of  1000 runs
# run # 670 of  1000 runs
# run # 671 of  1000 runs
# run # 672 of  1000 runs
# run # 673 of  1000 runs
# run # 674 of  1000 runs
# run # 675 of  1000 runs
# run # 676 of  1000 runs
# run # 677 of  1000 runs
# run # 678 of  1000 runs
# run # 679 of  1000 runs
# run # 680 of  1000 runs
# run # 681 of  1000 runs
# run # 682 of  1000 runs
# run # 683 of  1000 runs
# run # 684 of  1000 runs
# run # 685 of  1000 runs
# run # 686 of  1000 runs
# run # 687 of  1000 runs
# run # 688 of  1000 runs
# run # 689 of  1000 runs
# run # 690 of  1000 runs
# run # 691 of  1000 runs
# run # 692 of  1000 runs
# run # 693 of  1000 runs
# run # 694 of  1000 runs
# run # 695 of  1000 runs
# run # 696 of  1000 runs
# run # 697 of  1000 runs
# run # 698 of  1000 runs
# run # 699 of  1000 runs
# run # 700 of  1000 runs
# run # 701 of  1000 runs
# run # 702 of  1000 runs
# run # 703 of  1000 runs
# run # 704 of  1000 runs
# run # 705 of  1000 runs
# run # 706 of  1000 runs
# run # 707 of  1000 runs
# run # 708 of  1000 runs
# run # 709 of  1000 runs
# run # 710 of  1000 runs
# run # 711 of  1000 runs
# run # 712 of  1000 runs
# run # 713 of  1000 runs
# run # 714 of  1000 runs
# run # 715 of  1000 runs
# run # 716 of  1000 runs
# run # 717 of  1000 runs
# run # 718 of  1000 runs
# run # 719 of  1000 runs
# run # 720 of  1000 runs
# run # 721 of  1000 runs
# run # 722 of  1000 runs
# run # 723 of  1000 runs
# run # 724 of  1000 runs
# run # 725 of  1000 runs
# run # 726 of  1000 runs
# run # 727 of  1000 runs
# run # 728 of  1000 runs
# run # 729 of  1000 runs
# run # 730 of  1000 runs
# run # 731 of  1000 runs
# run # 732 of  1000 runs
# run # 733 of  1000 runs
# run # 734 of  1000 runs
# run # 735 of  1000 runs
# run # 736 of  1000 runs
# run # 737 of  1000 runs
# run # 738 of  1000 runs
# run # 739 of  1000 runs
# run # 740 of  1000 runs
# run # 741 of  1000 runs
# run # 742 of  1000 runs
# run # 743 of  1000 runs
# run # 744 of  1000 runs
# run # 745 of  1000 runs
# run # 746 of  1000 runs
# run # 747 of  1000 runs
# run # 748 of  1000 runs
# run # 749 of  1000 runs
# run # 750 of  1000 runs
# run # 751 of  1000 runs
# run # 752 of  1000 runs
# run # 753 of  1000 runs
# run # 754 of  1000 runs
# run # 755 of  1000 runs
# run # 756 of  1000 runs
# run # 757 of  1000 runs
# run # 758 of  1000 runs
# run # 759 of  1000 runs
# run # 760 of  1000 runs
# run # 761 of  1000 runs
# run # 762 of  1000 runs
# run # 763 of  1000 runs
# run # 764 of  1000 runs
# run # 765 of  1000 runs
# run # 766 of  1000 runs
# run # 767 of  1000 runs
# run # 768 of  1000 runs
# run # 769 of  1000 runs
# run # 770 of  1000 runs
# run # 771 of  1000 runs
# run # 772 of  1000 runs
# run # 773 of  1000 runs
# run # 774 of  1000 runs
# run # 775 of  1000 runs
# run # 776 of  1000 runs
# run # 777 of  1000 runs
# run # 778 of  1000 runs
# run # 779 of  1000 runs
# run # 780 of  1000 runs
# run # 781 of  1000 runs
# run # 782 of  1000 runs
# run # 783 of  1000 runs
# run # 784 of  1000 runs
# run # 785 of  1000 runs
# run # 786 of  1000 runs
# run # 787 of  1000 runs
# run # 788 of  1000 runs
# run # 789 of  1000 runs
# run # 790 of  1000 runs
# run # 791 of  1000 runs
# run # 792 of  1000 runs
# run # 793 of  1000 runs
# run # 794 of  1000 runs
# run # 795 of  1000 runs
# run # 796 of  1000 runs
# run # 797 of  1000 runs
# run # 798 of  1000 runs
# run # 799 of  1000 runs
# run # 800 of  1000 runs
# run # 801 of  1000 runs
# run # 802 of  1000 runs
# run # 803 of  1000 runs
# run # 804 of  1000 runs
# run # 805 of  1000 runs
# run # 806 of  1000 runs
# run # 807 of  1000 runs
# run # 808 of  1000 runs
# run # 809 of  1000 runs
# run # 810 of  1000 runs
# run # 811 of  1000 runs
# run # 812 of  1000 runs
# run # 813 of  1000 runs
# run # 814 of  1000 runs
# run # 815 of  1000 runs
# run # 816 of  1000 runs
# run # 817 of  1000 runs
# run # 818 of  1000 runs
# run # 819 of  1000 runs
# run # 820 of  1000 runs
# run # 821 of  1000 runs
# run # 822 of  1000 runs
# run # 823 of  1000 runs
# run # 824 of  1000 runs
# run # 825 of  1000 runs
# run # 826 of  1000 runs
# run # 827 of  1000 runs
# run # 828 of  1000 runs
# run # 829 of  1000 runs
# run # 830 of  1000 runs
# run # 831 of  1000 runs
# run # 832 of  1000 runs
# run # 833 of  1000 runs
# run # 834 of  1000 runs
# run # 835 of  1000 runs
# run # 836 of  1000 runs
# run # 837 of  1000 runs
# run # 838 of  1000 runs
# run # 839 of  1000 runs
# run # 840 of  1000 runs
# run # 841 of  1000 runs
# run # 842 of  1000 runs
# run # 843 of  1000 runs
# run # 844 of  1000 runs
# run # 845 of  1000 runs
# run # 846 of  1000 runs
# run # 847 of  1000 runs
# run # 848 of  1000 runs
# run # 849 of  1000 runs
# run # 850 of  1000 runs
# run # 851 of  1000 runs
# run # 852 of  1000 runs
# run # 853 of  1000 runs
# run # 854 of  1000 runs
# run # 855 of  1000 runs
# run # 856 of  1000 runs
# run # 857 of  1000 runs
# run # 858 of  1000 runs
# run # 859 of  1000 runs
# run # 860 of  1000 runs
# run # 861 of  1000 runs
# run # 862 of  1000 runs
# run # 863 of  1000 runs
# run # 864 of  1000 runs
# run # 865 of  1000 runs
# run # 866 of  1000 runs
# run # 867 of  1000 runs
# run # 868 of  1000 runs
# run # 869 of  1000 runs
# run # 870 of  1000 runs
# run # 871 of  1000 runs
# run # 872 of  1000 runs
# run # 873 of  1000 runs
# run # 874 of  1000 runs
# run # 875 of  1000 runs
# run # 876 of  1000 runs
# run # 877 of  1000 runs
# run # 878 of  1000 runs
# run # 879 of  1000 runs
# run # 880 of  1000 runs
# run # 881 of  1000 runs
# run # 882 of  1000 runs
# run # 883 of  1000 runs
# run # 884 of  1000 runs
# run # 885 of  1000 runs
# run # 886 of  1000 runs
# run # 887 of  1000 runs
# run # 888 of  1000 runs
# run # 889 of  1000 runs
# run # 890 of  1000 runs
# run # 891 of  1000 runs
# run # 892 of  1000 runs
# run # 893 of  1000 runs
# run # 894 of  1000 runs
# run # 895 of  1000 runs
# run # 896 of  1000 runs
# run # 897 of  1000 runs
# run # 898 of  1000 runs
# run # 899 of  1000 runs
# run # 900 of  1000 runs
# run # 901 of  1000 runs
# run # 902 of  1000 runs
# run # 903 of  1000 runs
# run # 904 of  1000 runs
# run # 905 of  1000 runs
# run # 906 of  1000 runs
# run # 907 of  1000 runs
# run # 908 of  1000 runs
# run # 909 of  1000 runs
# run # 910 of  1000 runs
# run # 911 of  1000 runs
# run # 912 of  1000 runs
# run # 913 of  1000 runs
# run # 914 of  1000 runs
# run # 915 of  1000 runs
# run # 916 of  1000 runs
# run # 917 of  1000 runs
# run # 918 of  1000 runs
# run # 919 of  1000 runs
# run # 920 of  1000 runs
# run # 921 of  1000 runs
# run # 922 of  1000 runs
# run # 923 of  1000 runs
# run # 924 of  1000 runs
# run # 925 of  1000 runs
# run # 926 of  1000 runs
# run # 927 of  1000 runs
# run # 928 of  1000 runs
# run # 929 of  1000 runs
# run # 930 of  1000 runs
# run # 931 of  1000 runs
# run # 932 of  1000 runs
# run # 933 of  1000 runs
# run # 934 of  1000 runs
# run # 935 of  1000 runs
# run # 936 of  1000 runs
# run # 937 of  1000 runs
# run # 938 of  1000 runs
# run # 939 of  1000 runs
# run # 940 of  1000 runs
# run # 941 of  1000 runs
# run # 942 of  1000 runs
# run # 943 of  1000 runs
# run # 944 of  1000 runs
# run # 945 of  1000 runs
# run # 946 of  1000 runs
# run # 947 of  1000 runs
# run # 948 of  1000 runs
# run # 949 of  1000 runs
# run # 950 of  1000 runs
# run # 951 of  1000 runs
# run # 952 of  1000 runs
# run # 953 of  1000 runs
# run # 954 of  1000 runs
# run # 955 of  1000 runs
# run # 956 of  1000 runs
# run # 957 of  1000 runs
# run # 958 of  1000 runs
# run # 959 of  1000 runs
# run # 960 of  1000 runs
# run # 961 of  1000 runs
# run # 962 of  1000 runs
# run # 963 of  1000 runs
# run # 964 of  1000 runs
# run # 965 of  1000 runs
# run # 966 of  1000 runs
# run # 967 of  1000 runs
# run # 968 of  1000 runs
# run # 969 of  1000 runs
# run # 970 of  1000 runs
# run # 971 of  1000 runs
# run # 972 of  1000 runs
# run # 973 of  1000 runs
# run # 974 of  1000 runs
# run # 975 of  1000 runs
# run # 976 of  1000 runs
# run # 977 of  1000 runs
# run # 978 of  1000 runs
# run # 979 of  1000 runs
# run # 980 of  1000 runs
# run # 981 of  1000 runs
# run # 982 of  1000 runs
# run # 983 of  1000 runs
# run # 984 of  1000 runs
# run # 985 of  1000 runs
# run # 986 of  1000 runs
# run # 987 of  1000 runs
# run # 988 of  1000 runs
# run # 989 of  1000 runs
# run # 990 of  1000 runs
# run # 991 of  1000 runs
# run # 992 of  1000 runs
# run # 993 of  1000 runs
# run # 994 of  1000 runs
# run # 995 of  1000 runs
# run # 996 of  1000 runs
# run # 997 of  1000 runs
# run # 998 of  1000 runs
# run # 999 of  1000 runs
# run # 1000 of  1000 runs
# array([[[59.67153385, 57.52884001],
#         [60.96875487, 58.39020125]],
#
#        [[52.91573496, 48.58681591],
#         [54.4844498 , 52.93270339]],
#
#        [[59.40283759, 55.08858266],
#         [60.62361503, 56.26546671]],
#
#        [[53.46758743, 47.95543724],
#         [54.61706261, 50.39783476]],
#
#        [[52.13591506, 47.21128097],
#         [53.45951715, 53.26966686]],
#
#        [[51.91572234, 45.88507452],
#         [52.91651278, 48.34539852]],
#
#        [[46.76978438, 40.63635225],
#         [49.85194586, 45.09357234]],
#
#        [[45.96739972, 40.35596301],
#         [49.80979316, 46.13680443]],
#
#        [[43.55529438, 40.66262081],
#         [47.21115636, 45.26851641]],
#
#        [[41.70013345, 37.36041961],
#         [45.792551  , 41.65696849]],
#
#        [[44.06389614, 42.03559958],
#         [46.43533924, 37.52753668]],
#
#        [[40.21052329, 35.45110422],
#         [44.23287105, 38.46337358]],
#
#        [[41.33188363, 34.54946342],
#         [47.63112505, 43.50064573]],
#
#        [[38.47673453, 35.26298501],
#         [42.59726986, 39.12033921]],
#
#        [[38.88299682, 31.24075534],
#         [45.58202358, 43.05798945]]])

# %%
final_inter_Q.shape
# Out:
# (50000, 2, 2)

# %%
final_Q[:,0,0]
# Out:
# array([59.67153385, 52.91573496, 59.40283759, 53.46758743, 52.13591506,
#        51.91572234, 46.76978438, 45.96739972, 43.55529438, 41.70013345,
#        44.06389614, 40.21052329, 41.33188363, 38.47673453, 38.88299682])

# %%
y_values = final_inter_Q[:, 0, 0]
y_values2 = final_Q[:,0,0]
t_arr = np.arange(0,)
x_values_15 = np.linspace(0, 25000 - 1, 15)
# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(range(24999), y_values[0:24999], linestyle='-')  # linestyle '-' for line plot
plt.plot(x_values_15, y_values2, label="15x2x2 [0,0] Index", linestyle='-', marker='o', color='r')

plt.xlabel("Period")
plt.ylim(30,67)
plt.ylabel("Value at [0,0] Index")
plt.title("Development of [0,0] Index Values over 50000 Periods")
plt.show()

# %%
y_values = final_inter_Q[:, 1, 1]
y_values2 = final_Q[:,1,1]
x_values_15 = np.linspace(0, 25000 - 1, 15)
# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(range(24999), y_values[0:24999], linestyle='-')  # linestyle '-' for line plot
plt.plot(x_values_15, y_values2, label="15x2x2 [1,1] Index", linestyle='-', marker='o', color='r')

plt.xlabel("Period")
plt.ylim(30,67)

plt.ylabel("Value at [1,1] Index")
plt.title("Development of [1,1] Index Values over 50000 Periods")
plt.show()

# %%
y_values = final_inter_Q[0:10, 1, 1]
y_values2 = final_Q[0:10,1,1]
print(y_values)
# Out:
# [ 0.          0.         59.0214821  57.48399072 55.12675401 55.68584279
#  53.2384373  54.76283857 53.73920696 54.09593075]

# %%
y_values = final_inter_Q[:, 1, 0]
y_values2 = final_Q[:,1,0]
t_arr = np.arange(0,)
x_values_15 = np.linspace(0, 25000 - 1, 15)
# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(range(24999), y_values[0:24999], linestyle='-')  # linestyle '-' for line plot
plt.plot(x_values_15, y_values2, label="15x2x2 [1,0] Index", linestyle='-', marker='o', color='r')

plt.xlabel("Period")
plt.ylim(30,67)

plt.ylabel("Value at [1,0] Index")
plt.title("Development of [1,0] Index Values over 50000 Periods")
plt.show()

# %%
def moving_avg(fst_arr, snd_arr, window_size):

    moving_averages = []
    moving_averages2 = []
    i = 0
    while i < len(fst_arr) - window_size + 1:
    
        # Calculate the average of current window
        window_average = np.sum(fst_arr[
        i:i+window_size]) / window_size
        window_average2 = np.sum(snd_arr[
        i:i+window_size]) / window_size
        
        # Store the average of current
        # window in moving average list
        moving_averages.append(window_average)
        moving_averages2.append(window_average2)

        
        # Shift window to right by one position
        i += 1
    return moving_averages, moving_averages2

def prof_means(prof_arr1, prof_arr2):
    return np.mean(prof_arr1, axis=0), np.mean(prof_arr2, axis=0)

# %%
samlet_prof, samlet_prof2 = prof_means(rewards_p1, rewards_p2)

# %%
profitability_arr, profitability_arr2 = moving_avg(samlet_prof, samlet_prof2, 1000)
avg_timend = time.time()
#print('ending moving average. time: ', (avg_timend - avgtime))
#np.savetxt("<file>.csv", moving_averages, delimiter = ',')
#print(moving_averages)

t_arr1 = np.arange(0,48999)
t_arr2 = np.arange(0,48999)
fig, ax = plt.subplots(figsize =(5.75, 2.6))
plt.plot(t_arr1,profitability_arr,'-',label='master Q')
plt.plot(t_arr2,profitability_arr2,'-', label='regular Q')
plt.title(f"{local_periods} periods, {learners} learners")
plt.axhline(y=1, color='k', linestyle = '--')
plt.axhline(y=3, color='k', linestyle = '--')
plt.xlabel("Time")
plt.ylabel("Average reward")
plt.ylim(0,5)
plt.legend()
plt.show()

# %%
first_fivep1 = rewards_p1[0:5,:]
first_fivep2 = rewards_p2[0:5,:]

last_fivep1 = rewards_p1[-5:,:]
last_fivep2 = rewards_p2[-5:,:]

# %%
first_prof1_5, first_prof2_5 = prof_means(first_fivep1, first_fivep2)
last_prof1_5, last_prof2_5 = prof_means(last_fivep1, last_fivep2)

# %%
profitability_first1_5, profitability_first2_5 = moving_avg(first_prof1_5, first_prof2_5, 1000)
t_arr1 = np.arange(0,48999)
t_arr2 = np.arange(0,48999)
fig, ax = plt.subplots(figsize =(5.75, 2.6))
plt.plot(t_arr1,profitability_first1_5,'-',label='First 5 periods, Master Q')
plt.plot(t_arr2,profitability_first2_5,'-', label='First 5 periods, 1/2 Grim')
#plt.axhline(y=0.125, color='k', linestyle = '--')
#plt.axhline(y=0.061, color='k', linestyle = '--')
plt.xlabel("Time")
plt.ylabel("Profitability")
#plt.ylim(0.00,0.15)
plt.legend()
plt.show()

# %%
profitability_last1_5, profitability_last2_5 = moving_avg(last_prof1_5, last_prof2_5, 1000)
t_arr1 = np.arange(0,48999)
t_arr2 = np.arange(0,48999)
fig, ax = plt.subplots(figsize =(5.75, 2.6))
plt.plot(t_arr1,profitability_last1_5,'-',label='Last 5 learners, Master Q')
plt.plot(t_arr2,profitability_last2_5,'-', label='Last 5 periods, t42t')
#plt.axhline(y=0.125, color='k', linestyle = '--')
#plt.axhline(y=0.061, color='k', linestyle = '--')
plt.xlabel("Time")
plt.ylabel("Profitability")
#plt.ylim(0.00,0.15)
plt.legend()
plt.show()

# %%
first_prof1_5, first_prof2_5 = prof_means(first_fivep1, first_fivep2)
last_prof1_5, last_prof2_5 = prof_means(last_fivep1, last_fivep2)

# %% [markdown]
# # ATTEMPTS WITH LONGER PERIODS: #

# %%
options = np.array([0,1])
init_Q = np.zeros((15,2,2))
#200.000 periods: 
#local_periods = 200000
#theta = 0.00004605
rewards_p1, rewards_p2, avg_prof, avg_prof2, final_Q2, choices1, choices2 = many_games(options, 200000, 0.3, 0.0000922, 200 ,0.95, final_Q)
final_Q2
# Out:
# run # 1 of  200 runs
# run # 2 of  200 runs
# run # 3 of  200 runs
# run # 4 of  200 runs
# run # 5 of  200 runs
# run # 6 of  200 runs
# run # 7 of  200 runs
# run # 8 of  200 runs
# run # 9 of  200 runs
# run # 10 of  200 runs
# run # 11 of  200 runs
# run # 12 of  200 runs
# run # 13 of  200 runs
# run # 14 of  200 runs
# run # 15 of  200 runs
# run # 16 of  200 runs
# run # 17 of  200 runs
# run # 18 of  200 runs
# run # 19 of  200 runs
# run # 20 of  200 runs
# run # 21 of  200 runs
# run # 22 of  200 runs
# run # 23 of  200 runs
# run # 24 of  200 runs
# run # 25 of  200 runs
# run # 26 of  200 runs
# run # 27 of  200 runs
# run # 28 of  200 runs
# run # 29 of  200 runs
# run # 30 of  200 runs
# run # 31 of  200 runs
# run # 32 of  200 runs
# run # 33 of  200 runs
# run # 34 of  200 runs
# run # 35 of  200 runs
# run # 36 of  200 runs
# run # 37 of  200 runs
# run # 38 of  200 runs
# run # 39 of  200 runs
# run # 40 of  200 runs
# run # 41 of  200 runs
# run # 42 of  200 runs
# run # 43 of  200 runs
# run # 44 of  200 runs
# run # 45 of  200 runs
# run # 46 of  200 runs
# run # 47 of  200 runs
# run # 48 of  200 runs
# run # 49 of  200 runs
# run # 50 of  200 runs
# run # 51 of  200 runs
# run # 52 of  200 runs
# run # 53 of  200 runs
# run # 54 of  200 runs
# run # 55 of  200 runs
# run # 56 of  200 runs
# run # 57 of  200 runs
# run # 58 of  200 runs
# run # 59 of  200 runs
# run # 60 of  200 runs
# run # 61 of  200 runs
# run # 62 of  200 runs
# run # 63 of  200 runs
# run # 64 of  200 runs
# run # 65 of  200 runs
# run # 66 of  200 runs
# run # 67 of  200 runs
# run # 68 of  200 runs
# run # 69 of  200 runs
# run # 70 of  200 runs
# run # 71 of  200 runs
# run # 72 of  200 runs
# run # 73 of  200 runs
# run # 74 of  200 runs
# run # 75 of  200 runs
# run # 76 of  200 runs
# run # 77 of  200 runs
# run # 78 of  200 runs
# run # 79 of  200 runs
# run # 80 of  200 runs
# run # 81 of  200 runs
# run # 82 of  200 runs
# run # 83 of  200 runs
# run # 84 of  200 runs
# run # 85 of  200 runs
# run # 86 of  200 runs
# run # 87 of  200 runs
# run # 88 of  200 runs
# run # 89 of  200 runs
# run # 90 of  200 runs
# run # 91 of  200 runs
# run # 92 of  200 runs
# run # 93 of  200 runs
# run # 94 of  200 runs
# run # 95 of  200 runs
# run # 96 of  200 runs
# run # 97 of  200 runs
# run # 98 of  200 runs
# run # 99 of  200 runs
# run # 100 of  200 runs
# run # 101 of  200 runs
# run # 102 of  200 runs
# run # 103 of  200 runs
# run # 104 of  200 runs
# run # 105 of  200 runs
# run # 106 of  200 runs
# run # 107 of  200 runs
# run # 108 of  200 runs
# run # 109 of  200 runs
# run # 110 of  200 runs
# run # 111 of  200 runs
# run # 112 of  200 runs
# run # 113 of  200 runs
# run # 114 of  200 runs
# run # 115 of  200 runs
# run # 116 of  200 runs
# run # 117 of  200 runs
# run # 118 of  200 runs
# run # 119 of  200 runs
# run # 120 of  200 runs
# run # 121 of  200 runs
# run # 122 of  200 runs
# run # 123 of  200 runs
# run # 124 of  200 runs
# run # 125 of  200 runs
# run # 126 of  200 runs
# run # 127 of  200 runs
# run # 128 of  200 runs
# run # 129 of  200 runs
# run # 130 of  200 runs
# run # 131 of  200 runs
# run # 132 of  200 runs
# run # 133 of  200 runs
# run # 134 of  200 runs
# run # 135 of  200 runs
# run # 136 of  200 runs
# run # 137 of  200 runs
# run # 138 of  200 runs
# run # 139 of  200 runs
# run # 140 of  200 runs
# run # 141 of  200 runs
# run # 142 of  200 runs
# run # 143 of  200 runs
# run # 144 of  200 runs
# run # 145 of  200 runs
# run # 146 of  200 runs
# run # 147 of  200 runs
# run # 148 of  200 runs
# run # 149 of  200 runs
# run # 150 of  200 runs
# run # 151 of  200 runs
# run # 152 of  200 runs
# run # 153 of  200 runs
# run # 154 of  200 runs
# run # 155 of  200 runs
# run # 156 of  200 runs
# run # 157 of  200 runs
# run # 158 of  200 runs
# run # 159 of  200 runs
# run # 160 of  200 runs
# run # 161 of  200 runs
# run # 162 of  200 runs
# run # 163 of  200 runs
# run # 164 of  200 runs
# run # 165 of  200 runs
# run # 166 of  200 runs
# run # 167 of  200 runs
# run # 168 of  200 runs
# run # 169 of  200 runs
# run # 170 of  200 runs
# run # 171 of  200 runs
# run # 172 of  200 runs
# run # 173 of  200 runs
# run # 174 of  200 runs
# run # 175 of  200 runs
# run # 176 of  200 runs
# run # 177 of  200 runs
# run # 178 of  200 runs
# run # 179 of  200 runs
# run # 180 of  200 runs
# run # 181 of  200 runs
# run # 182 of  200 runs
# run # 183 of  200 runs
# run # 184 of  200 runs
# run # 185 of  200 runs
# run # 186 of  200 runs
# run # 187 of  200 runs
# run # 188 of  200 runs
# run # 189 of  200 runs
# run # 190 of  200 runs
# run # 191 of  200 runs
# run # 192 of  200 runs
# run # 193 of  200 runs
# run # 194 of  200 runs
# run # 195 of  200 runs
# run # 196 of  200 runs
# run # 197 of  200 runs
# run # 198 of  200 runs
# run # 199 of  200 runs
# run # 200 of  200 runs
# array([[[49.11047789, 39.05453244],
#         [49.27223008, 46.76212891]],
#
#        [[57.67062164, 33.03282132],
#         [56.16634004, 57.8913748 ]],
#
#        [[59.80712904, 31.99443822],
#         [46.33409085, 58.52195303]],
#
#        [[59.99998832, 27.87878254],
#         [54.06777136, 58.72700739]],
#
#        [[59.99999999, 22.16361718],
#         [56.12529829, 59.0418591 ]],
#
#        [[60.        , 19.96336283],
#         [52.8790813 , 58.95467156]],
#
#        [[60.        , 19.74363957],
#         [41.1088787 , 58.46706236]],
#
#        [[60.        , 19.82605317],
#         [47.49235283, 57.2086214 ]],
#
#        [[60.        , 19.41812275],
#         [48.35619367, 51.80492535]],
#
#        [[60.        , 19.52201189],
#         [48.48283882, 43.1572202 ]],
#
#        [[60.        , 19.95043639],
#         [50.4578003 , 36.91642632]],
#
#        [[60.        , 19.90064619],
#         [47.30547478, 20.        ]],
#
#        [[60.        , 19.48934331],
#         [57.62972656, 20.        ]],
#
#        [[60.        , 19.95486608],
#         [57.88088528, 20.        ]],
#
#        [[60.        , 19.46646832],
#         [58.47322399, 20.        ]]])

# %%
samlet_prof, samlet_prof2 = prof_means(rewards_p1, rewards_p2)

# %%
samlet_prof, samlet_prof2 = prof_means(rewards_p1, rewards_p2)

profitability_arr, profitability_arr2 = moving_avg(samlet_prof, samlet_prof2, 1000)
avg_timend = time.time()
#print('ending moving average. time: ', (avg_timend - avgtime))
#np.savetxt("<file>.csv", moving_averages, delimiter = ',')
#print(moving_averages)

t_arr1 = np.arange(0,198999)
t_arr2 = np.arange(0,198999)
fig, ax = plt.subplots(figsize =(5.75, 2.6))
plt.plot(t_arr1,profitability_arr,'-',label='Master Q_learner')
plt.plot(t_arr2,profitability_arr2,'-', label='t4t -> grim')
plt.axhline(y=3, color='k', linestyle = '--')
plt.axhline(y=1, color='k', linestyle = '--')
plt.title('200.000 periods, 200 learners')
plt.xlabel("Time")
plt.ylabel("Avg. reward")
plt.ylim(0,5)
plt.legend()
plt.show()

# %%
Q = np.zeros((10,2,2))

all_choices1, all_choices2, reward_arr, reward_arr_p2, q_table = PD_game(Q, options, 10000, 0.3, 0.000322, 0.95)
# Out:
# interval 666.6666666666666
# Wrong dimensions
